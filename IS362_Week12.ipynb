# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

# %% [markdown]
# I went to http://developer.nytimes.com; I created my account; then I created New App, so I could get my API Key. I choose the "most popular API" and I decided to show most viewed articles for the last seven days.

# %%
api_key = 'WayD2utIdThd8zGfPszmI96A6OGVVok8'
url = 'https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

df = pd.read_json(response)
df
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2019 The New York Times Company....         1700
# 1      OK  Copyright (c) 2019 The New York Times Company....         1700
# 2      OK  Copyright (c) 2019 The New York Times Company....         1700
# 3      OK  Copyright (c) 2019 The New York Times Company....         1700
# 4      OK  Copyright (c) 2019 The New York Times Company....         1700
# 5      OK  Copyright (c) 2019 The New York Times Company....         1700
# 6      OK  Copyright (c) 2019 The New York Times Company....         1700
# 7      OK  Copyright (c) 2019 The New York Times Company....         1700
# 8      OK  Copyright (c) 2019 The New York Times Company....         1700
# 9      OK  Copyright (c) 2019 The New York Times Company....         1700
# 10     OK  Copyright (c) 2019 The New York Times Company....         1700
# 11     OK  Copyright (c) 2019 The New York Times Company....         1700
# ...
